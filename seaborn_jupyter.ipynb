# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
df1=sns.load_dataset('tips')

# %%
df2=sns.load_dataset('iris')

# %%
df3=sns.load_dataset('flights')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# y should be continuous and x has to be categorical

# %%
sns.barplot(x='tip',y='size',data=df1)

# %%
sns.factorplot(x='tip',y='size',data=df1)
# Out:
# C:\Users\BHAVYA\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.stripplot(x='tip',y='size',data=df1)

# %%
sns.swarmplot(x='tip',y='size',data=df1)

# %%
sns.violinplot(x='tip',y='size',data=df1)

# %%
sns.countplot(x='tip',data=df1)

# %%
sns.boxplot(x='tip',y='size',data=df1)

# %%
sns.barplot(x='sex',y='tip',data=df1,estimator=np.mean)

# %%
sns.factorplot(x='sex',y='size',data=df1)
# Out:
# C:\Users\BHAVYA\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.distplot(df1['tip'])

# %%
sns.pairplot(df1,hue='smoker')

# %%
sns.jointplot(x='tip',y='size',data=df1)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df1['total_bill'],bins=20,rug=True)

# %%
sns.jointplot(x='total_bill',y='tip',data=df1)

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='kde',cmap='Accent_r')

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='hex',cmap='rocket_r')

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='resid')

# %%
sns.kdeplot(df1['total_bill'])
sns.rugplot(df1['total_bill'])

# %%
sns.factorplot(x='smoker',y='total_bill',data=df1,kind='bar')

# %%
sns.countplot(x='day',hue='sex',data=df1)

# %%
df3.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
df32 = df3.pivot_table(values='passengers',index='year',columns='month')

# %%
df32.head(2)
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
#
# month  October  November  December
# year
# 1949       119       104       118
# 1950       133       114       140

# %%
#plt.figure(figsize=(12,22))
sns.heatmap(df32,cmap='coolwarm')#,annot=True

# %%
sns.clustermap(df32,cmap='coolwarm')

# %%
sns.lmplot(x="total_bill", y="tip", data=df1)

# %%
mean, cov = [4, 6], [(1.5, .7), (.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
sns.regplot(x=x, y=y, color="g")

# %%
pg=sns.PairGrid(df1)
pg.map_diag(plt.hist)
pg.map_upper(sns.kdeplot)
pg.map_lower(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-a967d5777044> in <module>
#       1 pg=sns.PairGrid(df1)
# ----> 2 pg.map_diag(plt.hist)
#       3 pg.map_upper(sns.kdeplot)
#       4 pg.map_lower(plt.scatter)
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %%
fg=sns.FacetGrid(df1,col='day',row='time')
fg.map(plt.hist,'total_bill')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-a0df01a14201> in <module>
#       1 fg=sns.FacetGrid(df1,col='day',row='time')
# ----> 2 fg.map(plt.hist,'total_bill')
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %%
fg=sns.FacetGrid(df1,col='day',row='time',hue='sex')
fg.map(plt.scatter,'total_bill','tip').add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-1c865f853281> in <module>
#       1 fg=sns.FacetGrid(df1,col='day',row='time',hue='sex')
# ----> 2 fg.map(plt.scatter,'total_bill','tip').add_legend()
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'

# %%
jg=sns.JointGrid(x='total_bill',y='tip',data=df1)
jg.plot(sns.regplot,sns.distplot)
